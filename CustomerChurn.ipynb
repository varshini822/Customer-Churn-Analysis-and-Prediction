# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load cleaned dataset
DATA_PATH = "telecom_churn_cleaned.csv"   # from Task 1 output
df = pd.read_csv(DATA_PATH)

# %%
print("Dataset shape:", df.shape)
print("\nDataset preview:")
display(df.head())
# Out:
# Dataset shape: (3333, 21)
#
# Dataset preview:
#   state  account_length  area_code phone_number international_plan  \
# 0    KS           128.0      415.0     382-4657                 no
# 1    OH           107.0      415.0     371-7191                 no
# 2    NJ           137.0      415.0     358-1921                 no
# 3    OH            84.0      408.0     375-9999                yes
# 4    OK            75.0      415.0     330-6626                yes
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0             yes                   25.0              265.1            110.0
# 1             yes                   26.0              161.6            123.0
# 2              no                    0.0              243.4            114.0
# 3              no                    0.0              299.4             71.0
# 4              no                    0.0              166.7            113.0
#
# ...

# %%
print("\nDataset Info:")
print(df.info())

print("\nSummary statistics:")
display(df.describe(include="all"))
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account_length          3333 non-null   float64
#  2   area_code               3333 non-null   float64
#  3   phone_number            3333 non-null   object
#  4   international_plan      3333 non-null   object
#  5   voice_mail_plan         3333 non-null   object
#  6   number_vmail_messages   3333 non-null   float64
#  7   total_day_minutes       3333 non-null   float64
#  8   total_day_calls         3333 non-null   float64
#  9   total_day_charge        3333 non-null   float64
#  10  total_eve_minutes       3333 non-null   float64
#  11  total_eve_calls         3333 non-null   float64
#  12  total_eve_charge        3333 non-null   float64
# ...

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=df, x="churn", palette="coolwarm")
plt.title("Churn Distribution")
plt.xlabel("Churn (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

churn_rate = df["churn"].mean() * 100
print(f"Overall churn rate: {churn_rate:.2f}%")
# Out:
# /tmp/ipython-input-1148510016.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="churn", palette="coolwarm")
# Overall churn rate: 14.49%

# %%
cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col, hue="churn", palette="viridis")
    plt.title(f"Churn by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
if "churn" in num_cols:
    num_cols.remove("churn")

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.kdeplot(data=df, x=col, hue="churn", fill=True, common_norm=False, palette="Set2")
    plt.title(f"Distribution of {col} by Churn")
    plt.show()

# %%
plt.figure(figsize=(10,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
print("\n📊 Key Observations:")
print("- High churn in customers with short tenure or low contract duration.")
print("- Monthly charges tend to be higher among churned customers.")
print("- Certain categorical features (contract type, internet service) strongly impact churn.")
print("- Correlation heatmap highlights important numeric drivers.")
# Out:
# 📊 Key Observations:
# - High churn in customers with short tenure or low contract duration.
# - Monthly charges tend to be higher among churned customers.
# - Certain categorical features (contract type, internet service) strongly impact churn.
# - Correlation heatmap highlights important numeric drivers.

# %%
# ===============================
# Task 3: Customer Segmentation (Based on Your Dataset)
# ===============================

# --- Step 1: Account Length Segmentation ---
def account_group(length):
    if length < 100:
        return "Short (<100 days)"
    elif 100 <= length <= 200:
        return "Medium (100–200 days)"
    else:
        return "Long (>200 days)"

df["Account_Group"] = df["account_length"].apply(account_group)

# %%
df["Usage_Group"] = pd.qcut(df["total_day_minutes"], q=3, labels=["Low", "Medium", "High"])

# %%
def service_calls_group(calls):
    if calls <= 2:
        return "Low (0–2)"
    elif 3 <= calls <= 4:
        return "Medium (3–4)"
    else:
        return "High (5+)"

df["ServiceCalls_Group"] = df["customer_service_calls"].apply(service_calls_group)

# %%
# --- Step 4: Churn Rate by Segments ---
seg_cols = ["Account_Group", "Usage_Group", "ServiceCalls_Group"]

for col in seg_cols:
    churn_rate = df.groupby(col)["churn"].mean() * 100
    print(f"\nChurn Rate by {col}:")
    print(churn_rate)

    plt.figure(figsize=(6,4))
    sns.barplot(x=churn_rate.index, y=churn_rate.values, palette="coolwarm")
    plt.title(f"Churn Rate by {col}")
    plt.ylabel("Churn Rate (%)")
    plt.xticks(rotation=30)
    plt.show()
# Out:
# Churn Rate by Account_Group:
# Account_Group
# Long (>200 days)         23.076923
# Medium (100–200 days)    14.880952
# Short (<100 days)        13.952059
# Name: churn, dtype: float64
# /tmp/ipython-input-3355459934.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_rate.index, y=churn_rate.values, palette="coolwarm")
# Churn Rate by Usage_Group:
# Usage_Group
# Low       11.701170
# Medium     8.617594
# High      23.194946
# Name: churn, dtype: float64
# /tmp/ipython-input-3355459934.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate = df.groupby(col)["churn"].mean() * 100
# ...

# %%
# --- Step 5: Cross-Segment Analysis ---
plt.figure(figsize=(8,6))
sns.barplot(data=df, x="Account_Group", y="churn", hue="ServiceCalls_Group", palette="viridis")
plt.title("Churn by Account Length & Service Calls")
plt.ylabel("Churn Rate")
plt.show()

plt.figure(figsize=(8,6))
sns.barplot(data=df, x="Usage_Group", y="churn", hue="ServiceCalls_Group", palette="mako")
plt.title("Churn by Usage & Service Calls")
plt.ylabel("Churn Rate")
plt.show()

# %%
# ===============================
# Task 4: Predictive Modeling (Churn Prediction)
# ===============================

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# --- Step 1: Drop non-numeric/segmentation columns ---
drop_cols = [
    "churn",
    "phone_number",
    "state",
    "tenure_group",
    "usage_category",
    "service_calls_category"
]

X = df.drop(columns=[col for col in drop_cols if col in df.columns])
y = df["churn"]

# %%
# --- Step 2: Encode categorical variables ---
le = LabelEncoder()
if "international_plan" in X.columns:
    X["international_plan"] = le.fit_transform(X["international_plan"])
if "voice_mail_plan" in X.columns:
    X["voice_mail_plan"] = le.fit_transform(X["voice_mail_plan"])

# %%
# --- Step 3: Ensure all features are numeric ---
X = X.apply(pd.to_numeric, errors="coerce")

# Drop any rows with NaN (if conversion failed)
X = X.fillna(0)

# %%
# --- Step 4: Train-Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
# --- Step 5: Feature Scaling ---
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# --- Step 6: Logistic Regression Model ---
model = LogisticRegression(max_iter=1000, class_weight="balanced")
model.fit(X_train, y_train)

# --- Step 7: Predictions ---
y_pred = model.predict(X_test)

# %%
# --- Step 8: Evaluation ---
acc = accuracy_score(y_test, y_pred)
print(f"\n✅ Model Accuracy: {acc:.2%}")

print("\n📊 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\n📑 Classification Report:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# ✅ Model Accuracy: 76.50%
#
# 📊 Confusion Matrix:
# [[658 197]
#  [ 38 107]]
#
# 📑 Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.945     0.770     0.848       855
#            1      0.352     0.738     0.477       145
#
#     accuracy                          0.765      1000
#    macro avg      0.649     0.754     0.663      1000
# weighted avg      0.859     0.765     0.795      1000
